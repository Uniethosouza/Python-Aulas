# %% [markdown]
# # Preparatório para a aula de Físico, Engenharia e Matemática - Parte 2 : Matplotlib

# %% [markdown]
# ### Visualização de Dados
# * A visualização de dados consiste na apresentação de informações através de
# elementos visuais, como gráficos, diagramas, mapas, tabelas, entre outros.
#     * Por meio dela, fica muito mais fácil analisar os resultados, auxiliando o processo
# de identificar padrões e tendências e tomar decisões.
#     * Boas visualizações de dados ajudam a descomplicar as informações, transmitindo
# uma mensagem clara e objetiva.

# %% [markdown]
# ### Benefícios da Visualização de Dados
# * Com o enorme volume de informações disponíveis, as ferramentas de
# visualização de dados são cada vez mais fundamentais para as empresas.
# * Benefícios:
#     * Apresentação mais envolvente / Absorção rápida das informações
#
#     * Facilita a tomada de decisão
#
#     * Auxilia a encontrar conexões importantes para solucionar os problemas da sua
# empresa

# %% [markdown]
# ### Matplotlib
# * Matplotlib é uma biblioteca de software para criação de gráficos e
# visualizações de dados em geral, feita para e da linguagem de programação
# Python e sua extensão de matemática NumPy
# * Criada pelo biólogo e neurocientista John D. Hunter, a biblioteca possui uma
# comunidade ativa atuando em seu desenvolvimento.
# * Oferece uma interface de programação orientada a objetos para incluir
# gráficos em aplicações usando toolkits de interface gráfica.
# * Ele permite que você trace gráficos diferentes, como gráficos de barras,
# dispersão, histogramas, espectros e muito mais.
#
# Para usar:
# ```python
#     import matplotlib.pyplot as plt
# ```
# * Pyplot
#     * Permitem a criação de figuras, uma área para exibir o gráfico na figura,
# desenhar linhas na área do gráfico, decorar o gráfico com rótulos, etc.
#         * No pyplot , vários estados são preservados após a chamada de uma função
# dentro de um contexto, simplificando assim o seu trabalho sobre a figura ou
# área de desenho atuais.
#
#         * Assim, você pode ter uma figura complexa formada por várias áreas de
# gráficos distintas, e o pyplot mantém para você informações sobre para cada
# área de desenho.
# 10

# %% [markdown]
# ### Criando um gráfico
# Podemos criar um objeto gráfico usando a função `subplot()` :

# %%
import matplotlib.pyplot as plt
plt.style.use(['science', 'notebook', 'grid'])

# %%
fig, ax = plt.subplots ()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.show()

# %% [markdown]
# Podemos criar um objeto gráfico usando a função `plot()`:

# %%
plt.plot([10,5,3,4,6,8])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# O método `plot()` executa o desenho nos gráficos "atuais", criando esses
# gráficos (e sua figura mãe ) se eles ainda não existirem

# %% [markdown]
# ## Anatomia de um Gráfico

# %% [markdown]
# <p align="center">
#   <img width="500" height="500" src= "https://matplotlib.org/3.1.1/_images/sphx_glr_anatomy_001.png">
# </p>

# %% [markdown]
# ## Anatomia de uma Figura

# %% [markdown]
# ## Figura
# * A figura mantém o controle de todos os Gráficos ( Axes ), um conjunto
# com os outros objetos (títulos, lendas da figura, etc ), e o canvas
# * Não se preocupe muito com o canvas:
#     * É o objeto que realmente faz o desenho para obter o seu gráfico, mas como
# o usuário é mais ou menos invisível para você.
# * Uma figura pode conter qualquer número de Gráficos ( Axes ), mas
# normalmente terá pelo menos um.
# 17

# %% [markdown]
# ## Gráficos ( Axes ou Plot )
# * É a região da imagem com o espaço de dados (um gráfico).
# * Uma determinada figura pode conter muitos Gráficos, mas um
# determinado objeto Axes só pode estar em uma Figura.
# * Os Gráficos contêm dois (ou três no caso de objetos do Eixo 3D) eixos
# de coordenadas, e que cuidam dos limites dos dados.
#     * Os limites de dados também podem ser controlados por meio dos métodos
# axes.Axes.set_xlim () e axes.Axes.set_ylim

# %% [markdown]
# ### Eixos ( Axis )
# * Estes são os objetos da linha numérica.
#
# * Eles cuidam de definir os limites de gráfico e gerar as marcas no eixo
# ( ticks ) e rótulos ( ticklabels ).
#
# * A localização das marcas é determinada por um objeto Localizador e as
# grades são formatadas por um Formatter .
#
# * A combinação do localizador correto e do formatter dá um controle muito
# fino sobre os locais de marca e rótulos.

# %% [markdown]
# #### IMPORTANTE : Tradução meio estranha
# __Cuidado com a diferença entre AXES x AXIS__
# * AXES:
#     * Gráfico
#     * Plot
# * AXIS:
#     * Eixo das coordenadas do gráfico
#     * Abscissa, ordenada

# %% [markdown]
# A maneira mais fácil de se criar uma figura é usando a função `figure()`:

# %%
fig = plt.figure () # an empty figure
fig, ax = plt.subplots () # single Axes

# %%
fig, axs = plt.subplots (2, 2)

# %% [markdown]
# ### Artistas ( Artists )
#
# * Basicamente tudo o que você pode ver na figura é um artista.
# * Isso inclui os objetos Figura, Gráficos e Eixo, objetos de texto, objetos
# Line2D...
# * Quando a figura é renderizada , todos os artistas são atraídos para a tela.
# * A maioria dos artistas está ligada a um gráfico:
#     * Um artista não pode ser compartilhado por múltiplos gráficos, ou movido de
# um para outro.

# %% [markdown]
# ### Títulos e rótulos
# * Podemos definir os títulos e rótulos dos eixos usando os métodos:
#     * Um Título é definido via set_title
#
#     * Uma etiqueta (ou rótulo) para o eixo X é definida via set_xlabel
#
#     * Uma etiqueta (ou rótulo) para o eixo Y é definida via set_ylabel

# %% [markdown]
# ### Criando um gráfico com título
# Podemos criar um título para a figura usando a função `title()`:

# %%
plt.plot( [10,5,3,4,6,8] )
plt.title("Titulo do Gráfico")
plt.show()

# %% [markdown]
# Podemos criar um objeto gráfico usando a função `set_title()`:

# %%
fig, ax = plt.subplots ()
ax.plot([1, 2, 3, 4], [1, 4, 2,3])
ax.set_title("Muito Fácil")
# Out:
# Text(0.5, 1.0, 'Muito Fácil')

# %% [markdown]
# ### Criando um gráfico com título e rótulos
# Podemos criar um objeto gráfico usando a função `set_title ()`, `set_xlabel ()` e
# `set_ylabel()`:

# %%
fig, ax = plt.subplots ()
ax.plot ([1, 2, 3, 4], [1, 4, 2, 3])
ax.set_title("Muito Facil")
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")
plt.show()

# %% [markdown]
# ### Modificando a linha...
# Podemos mudar o tipo da linha de dados passando parâmetros para a função `plot()`.

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 4]
fig, ax = plt.subplots ()
ax.plot(x, y, color='r', linestyle ='--', linewidth = 2)

# %% [markdown]
# ### Tipos de linhas - Linestyle:
#
# Tipo pelo teclado:
# <p align="center">
#   <img width="640" height="480" src= "https://www.cdslab.org/python/notes/visualization/2d/lineStyles.png">
# </p>
#
# Ou por argumento:
# <p align="center">
#   <img width="640" height="480" src= "https://matplotlib.org/3.1.0/_images/sphx_glr_linestyles_001.png">
# </p>

# %% [markdown]
# ### Cores
# Cores Básicas:
# <p align="center">
#   <img width="640" height="480" src= "https://i.pinimg.com/originals/13/87/f8/1387f899ca634009251d25da462db414.png">
# </p>
#
# Caso queira uma cor expecifica, utilizar o valor HEX

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 4]
fig, ax = plt.subplots ()
ax.plot(x, y, color='gold', linestyle ="--", linewidth = 2)
plt.show()

# %% [markdown]
# ### Adicionando um marcador na linha...
# Podemos usar um marcador na linha de dados passando parâmetros
# para a função `plot()`:

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
fig, ax = plt.subplots ()
ax.plot(x , y , marker = 'o')

# %% [markdown]
# ### Marcadores
#
# <p align="center">
#   <img width="640" height="480" src= "https://matplotlib.org/3.3.3/_images/sphx_glr_marker_reference_002.png">
#   <img width="640" height="480" src= "https://matplotlib.org/stable/_images/sphx_glr_marker_reference_001.png">
#
# </p>

# %% [markdown]
# ### Retirando a linha...
# Podemos retirar a linha de dados passando parâmetros para a função plot():

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
fig, ax = plt.subplots ()
ax.plot(x , y , marker = 'o', linestyle = 'None')
plt.show()

# %% [markdown]
# ### Atribuindo o nome dos eixos
# Podemos apresentar a legenda usando a função `legend()`:

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
fig, ax = plt.subplots ()
ax.plot(x , y , marker = 'o', linestyle = 'None')
ax.legend(["Dados obtidos"])
ax.set_xlabel = ('Eixo x')
ax.set_ylabel = ('Eixo y')
plt.show()

# %% [markdown]
# ### Mudando o espaçamento dos ticks
# Podemos mudar o espaçamento dos dados nos eixos usando a função
# `xticks()` e `yticks()`.

# %%
import numpy as np 

x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
fig, ax = plt.subplots ()
ax.plot(x , y , marker = 'o', linestyle = 'None')
ax.legend(["Dados obtidos"])
ax.set_xlabel = ('Eixo x')
ax.set_ylabel = ('Eixo y')
plt.xticks(np.arange(min(x), max(x)+0.1, 0.2), rotation = 90)
plt.yticks(np.arange(min(x), max(x)+0.1, 0.2))
plt.show()

# %% [markdown]
# ### Marcando a grade
# * Podemos criar uma grade para a figura com usando a função `grid()`:

# %% [markdown]
# ```python
#     ax.grid(color='r', linestyle='-'   , linewidth=1)
#     ax.grid(color='g', linestyle='--', linewidth =1)
#     ax.grid(color='b', linestyle='-.' , linewidth =1)
#     ax.grid(color='y', linestyle=':'   , linewidth =1)
# ```

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
fig, ax = plt.subplots()
ax.plot(x,y)
ax.legend(["Dados obtidos"])
ax.set_xlabel = ('Eixo x')
ax.set_ylabel = ('Eixo y')
ax.grid(color='g', linestyle=':', linewidth =1)
plt.xticks(np.arange(min(x), max(x)+0.1, 0.2), rotation = 90)
plt.yticks(np.arange(min(x), max(x)+0.1, 0.2))
plt.show()

# %% [markdown]
# ### Mais de um conjunto de dados
# * É possível imprimir mais de um conjunto de dados, várias linhas, no mesmo
# gráfico...

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3] 
z = [3, 5, 6, 7]
fig, ax = plt.subplots()
ax.plot(x , y , marker = 'x')
ax.plot(x , z , marker = 'o')
ax.legend(['Meus dados', 'Meus outros dados'])
ax.set_title("Muito Facil")
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")
plt.show()

# %% [markdown]
# ### Criando sub gráficos com títulos e espaço
# Para ajustar o espaço podemos usar a função `subplot_adjust()`:

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots (2,2)
plt.subplots_adjust(hspace =0.5)    #troque esse numero e aumentar/diminuira o espaçamento entre os graficos
axs[0,0].set_title ("Gráfico 0,0")
axs[0,1].set_title ("Gráfico 0,1")
axs[1,0].set_title ("Gráfico 1,0")
axs[1,1].set_title ("Gráfico 1,1")
# Out:
# Text(0.5, 1.0, 'Gráfico 1,1')

# %% [markdown]
# ### Tipos de gráficos
# A biblioteca matplotlib possui muitos tipos diferentes de gráficos:
# * Linha
#
# * Barra
#
# * Pizza
#
# * Histograma
#
# * Scatter plot
#
#
# * 3D plot
#
# * Image plot
#
# * Contour plot
#
# * Polar plot

# %% [markdown]
# #### Bar chart

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
fig, ax = plt.subplots()
ax.bar(x,y)
plt.show()

# %% [markdown]
# ### Gráfico de setores Pizza
# * Faz um gráfico de pizza de um array x.
#
# * A área fracionada de cada fatia é dada por x/soma(x).
#
# * As fatias são plotadas no sentido anti horário, por padrão
# começando no eixo x.

# %%
x = [1, 2, 3, 4]
fig, ax = plt.subplots()
ax.pie(x)
plt.show()

# %% [markdown]
# ### Gráfico de dispersão (Scatter plot)
# * É um gráfico de dispersão de y vs. x com marcador de tamanho
# e/ou cor variável.

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
fig, ax = plt.subplots()
ax.scatter(x,y)
plt.show()

# %% [markdown]
# ### Histograma
# * O histograma é a representação gráfica em colunas ou em barras
# de um conjunto de dados previamente tabulado e dividido em
# classes uniformes ou não uniformes.
#
# * É um gráfico que mostra a distribuição de acontecimentos
# registrados em todo o espectro, sendo muito importante para
# análise estatística.

# %%
x = [2,2,2,2,5,5,5,8,7,7,7,3,4,4,5]
fig, ax = plt.subplots()
ax.hist(x)
plt.show()

# %% [markdown]
# ### 3D

# %%
omega = 2
z_line=np.linspace(0,10,100)
x_line=np.cos(omega*z_line)
y_line=np.sin(omega*z_line)
ax = plt.axes(projection = '3d')
ax.plot3D(x_line,y_line,z_line)
# plt.figure(figsize=(20,20))
plt.show()

# %% [markdown]
# ### Criando Animações:

# %% [markdown]
# As animações requerem relacionar o tempo do seu problema com o quadro da animação e, em seguida, especificar os quadros por segundo
#
# * Abaixo está uma onda $ \ sin $ movendo-se a 3m / s. Traduza isso em uma animação

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

# %%
def f(x,t):
    return np.sin(x-3*t)

x = np.linspace(0, 10*np.pi, 1000)
t = np.arange(0, 24, 1/60)
X, T = np.meshgrid(x, t)
F = f(X, T)
plt.plot(x, F[1])

# %%
fig, ax = plt.subplots(1,1, figsize=(8,4))
ln1, = plt.plot([], [])
time_text = ax.text(0.65, 0.95, '', fontsize=15,
                    bbox=dict(facecolor='white', edgecolor='black'), 
                    transform=ax.transAxes)
ax.set_xlim(0,10*np.pi)
ax.set_ylim(-1.5, 1.5)
plt.legend([r"$y = \sin(x-3t)$"], loc = 4)
def animate(i):
    ln1.set_data(x, F[i])
    time_text.set_text('t={:.2f}'.format(i/60))
    
ani = animation.FuncAnimation(fig, animate, frames=240, interval=50)
ani.save('ani.gif',writer='pillow',fps=60,dpi=200)

# %% [markdown]
# ## Dicas Para mexer com gráficos

# %% [markdown]
# ### Alterar o Tamanho do gráfico
# * Como mudar o tamanho de 1 figura:
# ```python
#     plt.figure(figsize = ( horizontal, Vertical )) #A unidade esta em polegada
# ```
# * Caso queira mudar o tamanho de __TODAS__ as figuras:
# ```python
#     #No começo do codigo, digite:
#     plt.rcParams['figure.figsize'] = (x,y)
# ```

# %% [markdown]
# ### Como salvar o gráfico:
# * Salvando a figura:
# ```python
#     plt.savefig("nome.extensão") #Será salvo no mesmo diretório em que o codigo esta salvo
# ```
#     * Caso queria saber se o arquivo foi salvo sem sair do codigo, digite:
# ```python
#     !ls
# ```
# * Salvando em um local expecifico:
# ```python
#     plt.savefig("Path- Exemplo: User/Desktop/nome.extensão")
# ```
# * Tipos de extensão que pode ser salvos:
# <div , align = 'center'>
#
# | TIPO 	|
# |------	|
# | .png 	|
# | .pdf 	|
# | .svg 	|
# | .ps  	|
#
# </div>
#
# * Caso queira trabalhar com .png , recomenda-se aumentar o numero de DPI para melhorar a qualidade - (Padrão=100):
# ```python
#     plt.savefig("nome.png", dpi = 200 )
# ```

# %% [markdown]
# ### Texto dos Eixos não aparece por completo
# ```python
#     plt.xlabel("Nome do Eixo", fontsize = 30) #Altera o tamanho da letra
#     plt.savefig("nome.extensão", bbox_inches = 'tight' ) #O python vai tentar deixar da melhor maneira possivel
# ```

# %% [markdown]
# ### Simbolos Matemáticos nas figuras usando $TEX$:

# %%
import numpy as np
X = np.linspace(1,4,100)
y = X
y2 = X**2
y_log = np.log(X)
y_cos = np.cos(np.pi*X)

# %%
plt.plot(X,y2)
plt.title(r"$y = x^2_{Texto}$") #r - O python deixa a string em RAW. O $$ é para converter o texto para Tex
plt.show()

# %%
plt.plot(X,y_cos)
plt.text(2.5,0.75,r"$y = \cos(\pi x)$", size = 15)
plt.xlabel(r"Eixo $x$")
plt.ylabel(r"Eixo $y = \cos(\pi x)$")
plt.legend([r"$y = \cos(\pi x)$"], loc = 4)
plt.show()

# %%
x = np.linspace(0.5,100,1000)
y_frac = 2 + 1/(x**2)
plt.plot(x,y_frac)
plt.ylim(0,None)
plt.title(r"$\lim_{x\rightarrow\infty}\;2 + \frac{1}{x^2}$", fontsize = 20)
plt.show()

# %%
from matplotlib import rc 
rc('text',usetex = True)
x = np.linspace(10,100,1000)
y_frac = 2 + 1/(x**2)
y_frac2 = 1 + 1/((x-10)**2)

#plt.plot(x,y_frac)
plt.plot(x,y_frac2)
plt.ylim(0,None)
eq = (r'\begin{eqnarray*}'
      r'\lim_{x\rightarrow\infty}\; 2 +\frac {1} {x^2} &=&2 \\'
      r'\lim_{x\rightarrow\infty}\; 1 +\frac {1}{(x-10)^2}&=&1'
      r'\end{eqnarray*}')
plt.text(25,100,eq, size = 20);
plt.show()
# Out:
# C:\Users\thoma\AppData\Local\Temp/ipykernel_21232/355213502.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   y_frac2 = 1 + 1/((x-10)**2)

# %% [markdown]
# ### Linhas nos gráficos

# %%
X = np.linspace(0, 10, 1000)
Y = np.sin(np.pi*X/2) + 2
Y2 = 10 - (X-5)**2

# %% [markdown]
# axhline, axvline

# %%
plt.plot(X, Y, lw=4, label='sine wave')
plt.axhline(2, color='orangered', lw=4, label='baseline')
plt.legend();

# %%
plt.plot(X, Y2)
plt.axvline(5, ymin=0.2, ymax=.8);

# %% [markdown]
# ### Aplicando formas geometricas

# %%
from matplotlib.patches import Rectangle
np.random.seed(33)
a = np.random.normal(0,3,size = 50)
b = a + np.random.normal(0,3,size = 50)

# %%
plt.scatter( a , b , alpha = 0.7)
rect = Rectangle((0,0),8,12, fill= False, angle = 15)
plt.gca().add_patch(rect)

# %%
from matplotlib.patches import Circle
plt.rcParams['figure.figsize'] = (6,6)
plt.scatter( a , b , alpha = 0.7)
plt.xlim(-11,11)
plt.ylim(-11,11)
circle = Circle((0,0),4, fill = False)
plt.gca().add_patch(circle)
